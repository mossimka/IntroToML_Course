# %% [markdown]
# # HEADING1

# %% [markdown]
# ## HEADING2

# %% [markdown]
# ### HEADING3

# %% [markdown]
# <div align="center">
#     # Hello IML!
# </div>

# %% [markdown]
# <h1 align="center">Hello second time</h1>

# %% [markdown]
# **wowwowowo**

# %% [markdown]
# *italic*

# %% [markdown]
# - Pizza 1
# - Pizza 2
#   - Mini Pizza

# %% [markdown]
# 1. Cafe
# 2. Cafe
# 3. Cafe

# %% [markdown]
# [Github](https://github.com/mossimka)

# %% [markdown]
# ![pizza](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fwww.foodandwine.com%2Fthmb%2FWd4lBRZz3X_8qBr69UOu2m7I2iw%3D%2F1500x0%2Ffilters%3Ano_upscale()%3Amax_bytes(150000)%3Astrip_icc()%2Fclassic-cheese-pizza-FT-RECIPE0422-31a2c938fc2546c9a07b7011658cfd05.jpg&f=1&nofb=1&ipt=df75458f5b5bc842ce1acdee99204d575b3e80a499473c594a6d4e0ab068f5d8)

# %% [markdown]
# ![lol](/home/maxim-sarsekeyev/Pictures/ok_dave.png)

# %% [markdown]
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fadictosalinux.com%2Fwp-content%2Fuploads%2F2024%2F09%2FBiografia-Linus-Torvalds-Creador-Linux-1320x693.png&f=1&nofb=1&ipt=31a03015e0764427f79df52f1c36309ff5f1b8a3d9571e5390f97c4dc1724aa6" width="166"></img>

# %% [markdown]
# <table>
#     <tr>
# b        <td>Anotther pizza.</td>
#     </tr>
# </table

# %% [markdown]
# <p align="center">
#  <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fwallpapers.com%2Fimages%2Fhd%2Fcute-dog-2560-x-1600-background-m6oi2au6izjb9eus.jpg&f=1&nofb=1&ipt=5653dc223b4db142b3564da2766cb575b33081d676f96b017a2c084805cadf45" width="150">
#  <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fwww.animalspot.net%2Fwp-content%2Fuploads%2F2017%2F08%2FPictures-of-Penguin.jpg&f=1&nofb=1&ipt=772976f496df799d545a649951115c0aade019ccf8ba15631ac9baf86db5b61e" width="150">
#  <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fwww.savacations.com%2Fwp-content%2Fuploads%2F2021%2F02%2FBlog-Capybara-Pantanal-Brazil3.jpg&f=1&nofb=1&ipt=484709f9521828b1a77bccd4be8edc9fe228e5b617957ff1390ffaaba1622e89" width="150">
# </p>

# %%
def hello_word():
    print("I'm here")
hello_word()
# Out:
# I'm here

# %% [markdown]
# | Name | Age | Country |
# |-------|-----|---------|
# | Maxim | 20 | KZ |
# | Bob | 25 | UK |

# %% [markdown]
# ---

# %% [markdown]
# > Jupiter Notebook<br>
# > Hell

# %% [markdown]
# 1. Python
#    - ML
#    - Fast API
# 2. TS
#     - Frontend
#     - Backebd

# %% [markdown]
# $F = ma^2$

# %% [markdown]
# $$
# \int_4^5 y^2 d2 = \frac{1}{4}
# $$

# %% [markdown]
# ~~good~~

# %% [markdown]
# - [ ] Do homework
# - [x] Visit uni

# %% [markdown]
# <b style="color:green;">Why???!!??!</b>

# %% [markdown]
# Let's go ✅

# %% [markdown]
# ## What going on 🤠
# - [x] - Hehe 🤓
#       - Gry
# - [ ] - not done yet 🚫
