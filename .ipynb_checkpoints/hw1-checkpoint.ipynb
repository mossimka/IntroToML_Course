# %% [markdown]
# # Task 1: Create Normal Headings (5 marks)

# %% [markdown]
# Write Markdown to create:
# - A level 1 heading: "My Title"
# - A level 2 heading: "My Subtitle"
# - A level 3 heading: "My Section"

# %% [markdown]
# # My Title

# %% [markdown]
# ## My Subtitle

# %% [markdown]
# ### My Section

# %% [markdown]
# # Task 2: Center a Heading (10 marks)

# %% [markdown]
# Create a centered heading: **"Welcome to My Notebook"**.

# %% [markdown]
# <h1 style="text-align: center;" >
#     Welcome to My Notebook
# </div>

# %% [markdown]
# # Task 3: Insert an Image (10 marks)

# %% [markdown]
# Insert an image using the Markdown syntax:<br>
# Hint: Use any sample image from your computer (e.g., cat.png ) or a link to an online image.

# %% [markdown]
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fimg.freepik.com%2Fpremium-photo%2Fdepictions-divine-intervention-miracles-ancient-egyptian-mythology_1314467-171173.jpg&f=1&nofb=1&ipt=09cf97d912217e015d9fd1f6c021ff36997803f2727eb80e8c16bdf721313e3c" />

# %% [markdown]
# # Task 4: Resize an Image (10 marks)

# %% [markdown]
# Resize an image to 200px width using HTML inside Markdown.

# %% [markdown]
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fimg.freepik.com%2Fpremium-photo%2Fdepictions-divine-intervention-miracles-ancient-egyptian-mythology_1314467-171173.jpg&f=1&nofb=1&ipt=09cf97d912217e015d9fd1f6c021ff36997803f2727eb80e8c16bdf721313e3c" width="200" height="200"/>

# %% [markdown]
# # Task 5: Image + Text Side by Side (15 marks)

# %% [markdown]
# Insert an image on the left and some text on the right.

# %% [markdown]
# <div style="display: flex;"></div>

# %% [markdown]
# <div style="display: flex;">
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fimg.freepik.com%2Fpremium-photo%2Fdepictions-divine-intervention-miracles-ancient-egyptian-mythology_1314467-171173.jpg&f=1&nofb=1&ipt=09cf97d912217e015d9fd1f6c021ff36997803f2727eb80e8c16bdf721313e3c" width="200" height="200"/>
# <b>Machine Learning task5</b>
# </div>

# %% [markdown]
# # Task 6: Display 3 Images Side by Side (15 marks)

# %% [markdown]
# Insert three images next to each other in the same row.

# %% [markdown]
# <div style="display: flex;">
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fimg.freepik.com%2Fpremium-photo%2Fdepictions-divine-intervention-miracles-ancient-egyptian-mythology_1314467-171173.jpg&f=1&nofb=1&ipt=09cf97d912217e015d9fd1f6c021ff36997803f2727eb80e8c16bdf721313e3c" width="200" height="200"/>
# <img src="https://external-content.duckduckgo.com/iu/?u=http%3A%2F%2Fwww.freeimageslive.co.uk%2Ffiles%2Fimages008%2Freichstag_night.jpg&f=1&nofb=1&ipt=a905535d3b7ca995972681b1b63af6e0c5d11ca0390737cdc83815065f3730d2" width="200" height="200"/>
# <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fcdn.pixabay.com%2Fphoto%2F2022%2F08%2F07%2F07%2F14%2Fbig-ben-7370008_1280.jpg&f=1&nofb=1&ipt=ba27d8f121eb6d8b6fc1f8c29ed1c0d29dc600cb7f820be2f0e131e5f3c728aa" width="200" height="200"/>
# </div>

# %% [markdown]
# # Challenging Task: Centered Title with an Image (10 marks)

# %% [markdown]
# Create a centered heading: "My Favorite Animal" and display an image right below it, centered.

# %% [markdown]
# <div style="display: flex; align-items: center; flex-direction: column;">
#     <h1>My Favorite Animal</h1>
#     <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fcdn-fastly.petguide.com%2Fmedia%2F2022%2F02%2F16%2F8234719%2Fbelgian-shepherd.jpg%3Fsize%3D720x845%26nocrop%3D1&f=1&nofb=1&ipt=98c428f68a9d19f263ff799c8ae6d444e543b31767f4f94e02471b24c582417a"
#     height="200">
# </div>
