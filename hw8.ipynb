# %% [markdown]
# <h1 style="color: red; text-align: center;">Assignment 8: Probability Concepts
# (Questions)</h1>
# <h2 style="color: red;">Instructor: Dr. Khaled Mohamad</h2>

# %% [markdown]
# ---
#
# <h1 style="color: blue; text-align: center;">
#     Part 1: Handling missing values & Basic
# concepts in Probability
# </h1>
#
# ---

# %% [markdown]
# # Load the Dataset and Answer the Following Questions:

# %% [markdown]
# 1. How many null values are there in each column?
#     1. Replace the null value of column "wheelbase" with the max value of the same
# column.
#     2. Replace the null value of column "carwidth" with the Min value of the same column.
#     3. Use Linear Interpolation to change the null value of column "carheight"
#     4. Replace the null value of column "enginesize" with the mod of the same column.
#
# 3. What is the Probability that a Car is Sedan ?
# 4. What is the Probability that a car is Sedan and works with gas ?
# 5. What is the probability that a car is Sedan given it is a gas fuel type?
# 6. Given that the car height is higer than 65, find the probability that the car engin size is
# greater than 130?

# %% [markdown]
# ## Import necessary libraries, load the 'Cars.csv' dataset, display a data sample, determine dataset dimensions, and determine the summary statistics for quantitative and qualtitative columns.

# %%
import pandas as pd
import numpy as np
import seaborn as snsb
import matplotlib.pyplot as plt
from scipy.stats import norm, binom

# %%
df = pd.read_csv("datasets/Cars.csv")

df.head()
# Out:
#                     carname fueltype aspiration doornumber      carbody  \
# 0        alfa-romero giulia      gas        std        two  convertible
# 1       alfa-romero stelvio      gas        std        two  convertible
# 2  alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3               audi 100 ls      gas        std       four        sedan
# 4                audi 100ls      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# 0        rwd          front       88.6      168.8      64.1  ...       130.0
# 1        rwd          front       88.6      168.8      64.1  ...       130.0
# 2        rwd          front       94.5      171.2      65.5  ...       152.0
# 3        fwd          front       99.8      176.6      66.2  ...       109.0
# 4        4wd          front       99.4      176.6      66.4  ...       136.0
#
#    fuelsystem boreratio stroke  compressionratio horsepower  peakrpm  citympg  \
# 0        mpfi      3.47   2.68               9.0        111     5000       21
# 1        mpfi      3.47   2.68               9.0        111     5000       21
# 2        mpfi      2.68   3.47               9.0        154     5000       19
# 3        mpfi      3.19   3.40              10.0        102     5500       24
# 4        mpfi      3.19   3.40               8.0        115     5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 24 columns]

# %%
print(df.shape)
# Out:
# (205, 24)

# %%
df.describe(include=["object"])
# Out:
#               carname fueltype aspiration doornumber carbody drivewheel  \
# count             205      205        205        205     205        205
# unique            147        2          2          2       5          3
# top     toyota corona      gas        std       four   sedan        fwd
# freq                6      185        168        115      96        120
#
#        enginelocation enginetype cylindernumber fuelsystem
# count             205        205            205        205
# unique              2          7              7          8
# top             front        ohc           four       mpfi
# freq              202        148            159         94

# %%
df.describe()
# Out:
#         wheelbase   carlength    carwidth   carheight   curbweight  \
# count  194.000000  205.000000  185.000000  190.000000   205.000000
# mean    98.669588  174.049268   65.932973   53.738947  2555.565854
# std      5.934168   12.337289    2.113143    2.470452   520.680204
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.300000   64.200000   52.000000  2145.000000
# 50%     97.000000  173.200000   65.500000   54.100000  2414.000000
# 75%    101.800000  183.100000   66.600000   55.575000  2935.000000
# max    120.900000  208.100000   72.300000   59.800000  4066.000000
#
#        enginesize   boreratio      stroke  compressionratio  horsepower  \
# count  185.000000  205.000000  205.000000        205.000000  205.000000
# mean   124.081081    3.329756    3.255415         10.142537  104.117073
# std     38.528771    0.270844    0.313597          3.972040   39.544167
# min     61.000000    2.540000    2.070000          7.000000   48.000000
# 25%     97.000000    3.150000    3.110000          8.600000   70.000000
# 50%    110.000000    3.310000    3.290000          9.000000   95.000000
# 75%    141.000000    3.580000    3.410000          9.400000  116.000000
# max    308.000000    3.940000    4.170000         23.000000  288.000000
#
#            peakrpm     citympg  highwaympg         price
# count   205.000000  205.000000  205.000000    205.000000
# mean   5125.121951   25.219512   30.751220  13276.710571
# std     476.985643    6.542142    6.886443   7988.852332
# min    4150.000000   13.000000   16.000000   5118.000000
# 25%    4800.000000   19.000000   25.000000   7788.000000
# 50%    5200.000000   24.000000   30.000000  10295.000000
# 75%    5500.000000   30.000000   34.000000  16503.000000
# max    6600.000000   49.000000   54.000000  45400.000000

# %% [markdown]
# # Q1: How many null values are there in each column?

# %%
print(df.isnull().sum())
# Out:
# carname              0
# fueltype             0
# aspiration           0
# doornumber           0
# carbody              0
# drivewheel           0
# enginelocation       0
# wheelbase           11
# carlength            0
# carwidth            20
# carheight           15
# curbweight           0
# enginetype           0
# cylindernumber       0
# enginesize          20
# fuelsystem           0
# boreratio            0
# stroke               0
# compressionratio     0
# horsepower           0
# peakrpm              0
# citympg              0
# highwaympg           0
# price                0
# dtype: int64

# %% [markdown]
# # Q1_1: Replace the null value of column "wheelbase" with the max value of the same column

# %%
df['wheelbase'] = df['wheelbase'].fillna(df['wheelbase'].max())

# %% [markdown]
# # Q1_2: Replace the null value of column "carwidth" with the Min value of the same column

# %%
df['carwidth'] = df['carwidth'].fillna(df['carwidth'].min())

# %% [markdown]
# # Q1_3: Use Linear Interpolation to change the null value of column "carheight"

# %% [markdown]
# Hint: use interpolate function

# %%
df['carheight'] = df['carheight'].interpolate()

# %% [markdown]
# # Q1_4: Replace the null value of column "enginesize" with the mod of the same column and check how many null values we have

# %%
df['enginesize'] = df['enginesize'].fillna(df['enginesize'].mode()[0])

# %%
df.isnull().sum()
# Out:
# carname             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# # Q2: What is the Probability that the Car is Sedan ? (1 mark)

# %%
total_cars = len(df)

sedan = df[df['carbody'] == "sedan"]

sedan_p = len(sedan) / total_cars
print(sedan_p)
# Out:
# 0.4682926829268293

# %% [markdown]
# # Q3: What is the Probability that the car is Sedan and works with gas ?

# %%
sedan_gas = df[(df['carbody'] == "sedan") & ((df['fueltype'] == "gas"))]

sedan_gas_p = len(sedan_gas) / total_cars
print(sedan_gas_p)
# Out:
# 0.3951219512195122

# %% [markdown]
# # Q4:What is the probability that a car is Sedan given it is a gas fuel type?

# %%
gas = df[df['fueltype'] == "gas"]

gas_sedan = gas[gas['carbody'] == "sedan"]

gas_sedan_p = len(gas_sedan) / len(gas)
print(gas_sedan_p)
# Out:
# 0.43783783783783786

# %% [markdown]
# # Q5: Given that the car height is higer than 50, find the probability that the car engin size is greater than 130?

# %%
higher = df[df['carheight'] > 50]

high_engine = higher[higher['enginesize'] > 130]
print(len(high_engine) / len(higher))
# Out:
# 0.2916666666666667

# %% [markdown]
# ---
#
# <h1 style="color: blue; text-align: center;">
#     Part 2: Probability Functions
# </h1>
#
# ---

# %% [markdown]
# # Q6: Load dataset 'students.csv' and show first rows, shape, and compute the skewness.

# %%
df = pd.read_csv("datasets/students.csv")

# %%
df.head()
# Out:
#    stud.id                 name  gender  age  height  weight    religion  \
# 0   833917  Gonzales, Christina  Female   19     160    64.8      Muslim
# 1   898539       Lozano, T'Hani  Female   19     172    73.0       Other
# 2   379678       Williams, Hanh  Female   22     168    70.6  Protestant
# 3   807564          Nem, Denzel    Male   19     183    79.7       Other
# 4   383291      Powell, Heather  Female   21     175    71.4    Catholic
#
#    nc.score semester                   major                       minor  \
# 0      1.91      1st       Political Science             Social Sciences
# 1      1.56      2nd         Social Sciences  Mathematics and Statistics
# 2      1.24      3rd         Social Sciences  Mathematics and Statistics
# 3      1.37      2nd  Environmental Sciences  Mathematics and Statistics
# 4      1.46      1st  Environmental Sciences  Mathematics and Statistics
#
#    score1  score2  online.tutorial  graduated  salary
# 0     NaN     NaN                0          0     NaN
# 1     NaN     NaN                0          0     NaN
# 2    45.0    46.0                0          0     NaN
# 3     NaN     NaN                0          0     NaN
# 4     NaN     NaN                0          0     NaN

# %%
df.shape
# Out:
# (8239, 16)

# %%
df.skew(numeric_only=True)
# Out:
# stud.id            0.018612
# age                4.427823
# height            -0.009244
# weight             0.651004
# nc.score           0.446834
# score1            -0.318819
# score2            -0.304878
# online.tutorial    0.467502
# graduated          1.403900
# salary             0.273835
# dtype: float64

# %% [markdown]
# # Q7: What is the probability that the salary is greater than 20000 and less than 30000 ?

# %%
# 1
sns.histplot(df['salary'], bins=30, kde=True)
plt.title("Salary Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 # 1
# ----> 2 sns.histplot(df['salary'], bins=30, kde=True)
#       3 plt.title("Salary Distribution")
#       4 plt.show()
#
# NameError: name 'sns' is not defined

# %%
df['salary'].skew()

# %% [markdown]
# Distibution is approximately normal with slight right skew

# %%
# 2
mean = df['salary'].mean()
std = df['salary'].std()

print(mean, std)plt.subplot(1, 2, 2);

# %%
# 3
z1 = (20000 - mean) / std
z2 = (30000 - mean) / std

# %%
# 4
prob = norm.cdf(z2) - norm.cdf(z1)
print("Probability:", prob)

# %% [markdown]
# # Q8: A factory produces 200 chips with defect rate 8%. Answer the following questions:
# 1. What is the distribution name of this problem, based on the following questions ?
# 2. What is the probability of getting exactly 14 defective chips ?
# 3. At least 14 defective ?
# 4. At most 15 defective ?
# 5. Expected defects and standard deviation
#
# You should use the right distribution function from scipy.stats to proceed with the answers

# %% [markdown]
# 1) This is Binomial Distribution
#
# Because:
# - fixed number of trials (n = 200)
# - probability of success constant (p = 0.08)
# - success/failure outcome

# %%
# 2
n = 200
p = 0.08

prob_14 = binom.pmf(14, n, p)
print(prob_14)

# %%
# 3
prob_at_least_14 = 1 - binom.cdf(13, n, p)
print(prob_at_least_14)

# %%
# 4
prob_at_most_15 = binom.cdf(15, n, p)
print(prob_at_most_15)

# %%
# 5
expected = n * p
std = (n * p * (1 - p)) ** 0.5

print("Expected:", expected)
print("Std:", std)

# %%
df.head()
# Out:
#    stud.id                 name  gender  age  height  weight    religion  \
# 0   833917  Gonzales, Christina  Female   19     160    64.8      Muslim
# 1   898539       Lozano, T'Hani  Female   19     172    73.0       Other
# 2   379678       Williams, Hanh  Female   22     168    70.6  Protestant
# 3   807564          Nem, Denzel    Male   19     183    79.7       Other
# 4   383291      Powell, Heather  Female   21     175    71.4    Catholic
#
#    nc.score semester                   major                       minor  \
# 0      1.91      1st       Political Science             Social Sciences
# 1      1.56      2nd         Social Sciences  Mathematics and Statistics
# 2      1.24      3rd         Social Sciences  Mathematics and Statistics
# 3      1.37      2nd  Environmental Sciences  Mathematics and Statistics
# 4      1.46      1st  Environmental Sciences  Mathematics and Statistics
#
#    score1  score2  online.tutorial  graduated  salary
# 0     NaN     NaN                0          0     NaN
# 1     NaN     NaN                0          0     NaN
# 2    45.0    46.0                0          0     NaN
# 3     NaN     NaN                0          0     NaN
# 4     NaN     NaN                0          0     NaN

# %%
mean = df['salary'].mean()

# %%
std = df['salary'].std()

# %%
p = binom.cdf(z2) - binom.cdf(z1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 p = binom.cdf(z2) - binom.cdf(z1)
#
# File ~/anaconda3/lib/python3.12/site-packages/scipy/stats/_distn_infrastructure.py:3489, in rv_discrete.cdf(self, k, *args, **kwds)
#    3470 def cdf(self, k, *args, **kwds):
#    3471     """Cumulative distribution function of the given RV.
#    3472
#    3473     Parameters
#    (...)
#    3487
#    3488     """
# -> 3489     args, loc, _ = self._parse_args(*args, **kwds)
#    3490     k, loc = map(asarray, (k, loc))
#    3491     args = tuple(map(asarray, args))
#
# TypeError: _parse_args() missing 2 required positional arguments: 'n' and 'p'
